# %%
f1 = open("myheart.csv", "r")

lista = []
for linha in f1:
    campos = linha.split(",")
    lista.append(campos)

def numeroFM():
    totalF= 0
    totalM = 0
    for i in lista:
        if i[1] == "F":
            totalF = totalF + 1
        elif i[1] == "M":
            totalM = totalM +1
        resultado = (totalF, totalM)
    return resultado

def totaldoentes():
    resultadoF = 0
    resultadoM = 0
    for i in lista:
        if i[1] == "F" and i[-1] =="1\n":
            resultadoF = resultadoF + 1
        elif i[1]== "M" and i[-1] == "1\n":
            resultadoM = resultadoM +1
        resultado1 = (resultadoF, resultadoM)
    return resultado1


def distrib_idades1():
    res1 = 0
    res2 = 0
    res3 = 0
    res4 = 0
    res5 = 0
    res6 = 0
    res7 = 0
    res8 = 0
    res9 = 0
    res10 = 0
    for i in lista:
        if i[-1] == "1\n":
            if i[0]>= str(30) and i[0]<=str(34):
                res1 = res1 + 1
            elif i[0]>str(34) and i[0]<=str(39):
                res2 = res2 + 1
            elif i[0]>str(40) and i[0]<=str(44):
                res3 = res3 + 1 
            elif i[0]>str(44) and i[0]<=str(48):
                res4 = res4 +1
            elif i[0]> str(48) and i[0]<=str(52):
                res5 = res5 + 1
            elif i[0] > str(52) and i[0]<= str(56):
                res6= res6 +1
            elif i[0] > str(56) and i[0]<=str(60):
                res7 = res7 +1
            elif i[0] > str(60) and i[0]<= str(64):
                res8 = res8 +1
            elif i[0] > str(64) and i[0] <= str(68):
                res9 = res9 +1
            elif i[0] > str(68) and i[0] <= str(72):
                res10 = res10 +1
    a = [("[30,34]", res1), ("[35,39]", res2), ("[40,44]", res3), ("[44,48]",res4), ("[48,52]", res5), ("[52,56]", res6), ("[56,60]", res7), ("[60,64]", res8), ("[64,68]", res9), ("[68,72]", res10)]
    return a

def colestrolnivel():
    l = []
    for i in lista:
        a = (i[3], i[-1])
        l.append(a)
        nivel1 = 0
        nivel2 =0 
        nivel3 = 0
        nivel4= 0
        nivel5 = 0
        nivel6 = 0
        nivel7 = 0
        nivel8 = 0
        nivel9 = 0
        nivel10 = 0
        nivel11 = 0
        nivel12 = 0
        nivel13 = 0
        nivel14 = 0
        nivel15 = 0
        nivel16 = 0
        nivel17 = 0
        nivel18 = 0
        nivel19 = 0
        nivel20 = 0
        nivel21 = 0
        nivel22 = 0
        nivel23 = 0
        nivel24 = 0
        nivel25 = 0
        nivel26 = 0
        nivel27 = 0
        nivel28 = 0
        nivel29 = 0
        nivel30 = 0
        nivel31 = 0
        nivel32 = 0
        nivel33 = 0
        nivel34 = 0
        nivel35 = 0
        nivel36 = 0
        for a in l:
            colestrol, doença = a
            if doença == "1\n":
                if int(colestrol) >= 0 and int(colestrol) <= 10:
                    nivel1 = nivel1 + 1
                elif int(colestrol) > 90 and int(colestrol) <= 100:
                    nivel2 = nivel2 + 1
                elif int(colestrol) > 100 and int(colestrol) <= 110:
                    nivel3 = nivel3 + 1
                elif int(colestrol) > 110 and int(colestrol) <= 120:
                    nivel4 = nivel4 + 1
                elif int(colestrol) > 120 and int(colestrol) <= 130:
                    nivel5 = nivel5 + 1
                elif int(colestrol) > 130 and int(colestrol) <= 140:
                    nivel6 = nivel6 + 1
                elif int(colestrol) > 140 and int(colestrol) <= 150:
                    nivel7 = nivel7 + 1
                elif int(colestrol) > 150 and int(colestrol) <= 160:
                    nivel8 = nivel8 + 1
                elif int(colestrol) > 160 and int(colestrol) <= 170:
                    nivel9 = nivel9 + 1
                elif int(colestrol) > 170 and int(colestrol) <= 180:
                    nivel10 = nivel10 + 1
                elif int(colestrol) > 180 and int(colestrol) <= 190:
                    nivel11 = nivel11 + 1
                elif int(colestrol) > 190 and int(colestrol) <= 200:
                    nivel12 = nivel12 + 1
                elif int(colestrol) > 200 and int(colestrol) <= 210:
                    nivel13 = nivel13 + 1
                elif int(colestrol) > 210 and int(colestrol) <= 220:
                    nivel14 = nivel14 + 1
                elif int(colestrol) > 220 and int(colestrol) <= 230:
                    nivel15 = nivel15 + 1
                elif int(colestrol) > 230 and int(colestrol) <= 240:
                    nivel16 = nivel16 + 1
                elif int(colestrol) > 240 and int(colestrol) <= 250:
                    nivel17 = nivel17 + 1
                elif int(colestrol) > 250 and int(colestrol) <= 260:
                    nivel18 = nivel18+ 1
                elif int(colestrol) > 260 and int(colestrol) <= 270:
                    nivel19 = nivel19 + 1
                elif int(colestrol) > 270 and int(colestrol) <= 280:
                    nivel20 = nivel20 + 1
                elif int(colestrol) > 280 and int(colestrol) <= 290:
                    nivel21 = nivel21 + 1
                elif int(colestrol) > 290 and int(colestrol) <= 300:
                    nivel22 = nivel22 + 1
                elif int(colestrol) > 300 and int(colestrol) <= 310:
                    nivel23 = nivel23 + 1
                elif int(colestrol) > 310 and int(colestrol) <= 320:
                    nivel24 = nivel24 + 1
                elif int(colestrol) > 330 and int(colestrol) <= 340:
                    nivel25 = nivel25 + 1
                elif int(colestrol) > 340 and int(colestrol) <= 350:
                    nivel26 = nivel26 + 1
                elif int(colestrol) > 350 and int(colestrol) <= 360:
                    nivel27 = nivel27 + 1
                elif int(colestrol) > 360 and int(colestrol) <= 370:
                    nivel28 = nivel28 + 1
                elif int(colestrol) > 380 and int(colestrol) <= 390:
                    nivel29 = nivel29 + 1
                elif int(colestrol) > 390 and int(colestrol) <= 400:
                    nivel30 = nivel30 + 1
                elif int(colestrol) > 400 and int(colestrol) <= 410:
                    nivel31 = nivel31 + 1
                elif int(colestrol) > 460 and int(colestrol) <= 470:
                    nivel32 = nivel32 + 1
                elif int(colestrol) > 490 and int(colestrol) <= 500:
                    nivel33 = nivel33 + 1
                elif int(colestrol) > 510 and int(colestrol) <= 520:
                    nivel34 = nivel34 + 1
                elif int(colestrol) > 520 and int(colestrol) <= 530:
                    nivel35 = nivel35 + 1
                elif int(colestrol) > 600 and int(colestrol) <= 610:
                    nivel36 = nivel36 + 1    
    resultado = [("nivel1", nivel1), ("nivel2", nivel2), ("nivel3", nivel3), ("nivel4",nivel4),("nivel5", nivel5), ("nivel6", nivel6), ("nivel7", nivel7),("nivel8", nivel8), ("nivel9",nivel9), ("nivel10", nivel10),("nivel11", nivel11), ("nivel12", nivel12),("nivel13",nivel13), ("nivel14",nivel14),("nivel15", nivel15), ("nivel16", nivel16), ("nivel17", nivel17), ("nivel18", nivel18), ("nivel18", nivel18), ("nivel19", nivel19), ("nivel20", nivel20), ("nivel21", nivel21), ("nivel22",nivel22), ("nivel23",nivel23), ("nivel24", nivel24), ("nivel25", nivel25), ("nivel26", nivel26), ("nivel27",nivel27), ("nivel28",nivel28),("nivel29",nivel29), ("nivel30",nivel30), ("nivel31",nivel31), ("nivel32",nivel32), ("nivel33",nivel33), ("nivel34", nivel34), ("nivel35", nivel35), ("nivel36",nivel36)]
    return resultado

def tabeladistFM():
    x = numeroFM()
    y = totaldoentes()
    print("         ", "TOTAL" , " ", "S/DOENÇA" , " ", "C/DOENÇA" )
    print("======================================================")
    print("FEMININO"," ", x[0], "     ", x[0]-y[0],"     ", y[0])
    print("MASCULNO"," ", x[1], "     ", x[1]-y[1],"     ", y[1])

def tabelaniveis():
    x = colestrolnivel()
    print("NIVEIS", "         ", "NÚMERO")
    for i in x:
        nivel, numero = i
        print(nivel ,"         ", numero)

def tabelaidades():
    x = distrib_idades1()
    print("", "IDADE", "       ", "NÚMERO")
    for i in x:
        idade, numero = i
        print(idade, "       ", numero)

def menu():
     print("","(1) Distribuição da doença por sexo ", "\n", "(2) Distribuição da doença por idades",  "\n","(3) Distribuição da doença por níveis de colestrol", "\n", "(0) SAIR")


#menu==========================================================================
menu()
opção = int(input("Qual é a opção que pretende realizar?"))
while opção !=0:
    if opção == 1:
        tabeladistFM()
    elif opção ==2:
        tabelaidades()
    elif opção == 3:
        tabelaniveis()
    else:
        print("Opção não disponível!")
    print("============================================")
    menu()
    opção = int(input("Qual é a opção que pretende realizar?"))
if opção == 0:
    print("Escolheu sair do programa! Obrigada")


f1.close()
